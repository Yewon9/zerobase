# %% [markdown]
# ### 숫자로 이루어진 리스트에서 사용자가 입력한 숫자를 검색하는 모듈을 다음 요건에 따라 만들어보자.
# ![image.png](attachment:32c0c397-ab1a-448c-8326-edc0c658dbdd.png)

# %%
import random

# %%
def searchNumberByLineAlgorithm(ns, sn):
    searchResultIdx = -1
    print(f'Numbers : {ns}')
    print(f'Search Numbers : {sn}')

    n = 0
    while True:
        if n == len(ns):
            print('Search FAIL !')
            break
        elif ns[n] == sn:
            searchResultIdx = n
            print('Search SUCCESS !')
            print(f'Search result INDEX : {searchResultIdx}')
            break
        n += 1

    return searchResultIdx

# %%
if __name__ == '__main__':
    rNums = random.sample(range(1, 21), 10)
    searchNum = int(input('input search number : '))

    resultIdx = searchNumberByLineAlgorithm(rNums, searchNum)
    if resultIdx == -1:
        print('No Result found')
        print(f'Search result INDEX : {resultIdx}')
    else:
        print('>>> Search Results <<<')
        print(f'Search result INDEX : {resultIdx}')
        print(f'Search result NUMBER : {rNums[resultIdx]}')
# Out:
# input search number :  7
# Numbers : [12, 8, 7, 13, 4, 3, 1, 10, 5, 18]
# Search Numbers : 7
# Search SUCCESS !
# Search result INDEX : 2
# >>> Search Results <<<
# Search result INDEX : 2
# Search result NUMBER : 7
